# %%
import pandas as pd
import numpy as np

# Create a Series from a list
data = [10, 20, 30, 40, 50]
s = pd.Series(data)

print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
In [3]: p = pd.Series([1, 3, 5, np.nan, 6, 8])



In [4]: p
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)

dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.380406  0.028177 -1.017876 -1.163503
# 2013-01-02  0.867438 -1.966481 -0.957541  0.356254
# 2013-01-03  0.015313  1.210952  0.696286 -0.460985
# 2013-01-04  1.832450 -2.793149  0.389481 -0.139372
# 2013-01-05 -0.304531 -1.946036 -0.943141  0.796171
# 2013-01-06  1.739194 -1.331359 -0.197241  0.101344

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])

# %%
df1.loc[dates[0] : dates[1], "E"] = 1

# %%
df1
# Out:
#                    A         B         C         D    E
# 2013-01-01 -0.380406  0.028177 -1.017876 -1.163503  1.0
# 2013-01-02  0.867438 -1.966481 -0.957541  0.356254  1.0
# 2013-01-03  0.015313  1.210952  0.696286 -0.460985  NaN
# 2013-01-04  1.832450 -2.793149  0.389481 -0.139372  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C         D    E
# 2013-01-01 -0.380406  0.028177 -1.017876 -1.163503  1.0
# 2013-01-02  0.867438 -1.966481 -0.957541  0.356254  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C         D    E
# 2013-01-01 -0.380406  0.028177 -1.017876 -1.163503  1.0
# 2013-01-02  0.867438 -1.966481 -0.957541  0.356254  1.0
# 2013-01-03  0.015313  1.210952  0.696286 -0.460985  5.0
# 2013-01-04  1.832450 -2.793149  0.389481 -0.139372  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      E
# 2013-01-01  False  False  False  False  False
# 2013-01-02  False  False  False  False  False
# 2013-01-03  False  False  False  False   True
# 2013-01-04  False  False  False  False   True

# %%
df.mean()
# Out:
# A    0.628243
# B   -1.132983
# C   -0.338339
# D   -0.085015
# dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)

# %%
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

# %%
s
# Out:
# 0       A
# 1       B
# 2       C
# 3    Aaba
# 4    Baca
# 5     NaN
# 6    CABA
# 7     dog
# 8     cat
# dtype: object

# %%
df2 = pd.DataFrame(np.random.randn(10, 4))

# %%
df2
# Out:
#           0         1         2         3
# 0 -0.145894  0.805844  0.537868 -0.352405
# 1  1.447758 -0.144260  0.443920  1.216330
# 2 -0.611848 -1.657801  0.419867  0.456660
# 3 -0.216031 -0.515023  0.509460  2.874654
# 4 -0.462560  1.292320 -1.324338  0.225615
# 5  2.048822  0.814367  0.149044  1.109156
# 6 -1.170663 -1.536714  0.301065  0.898427
# 7 -0.631017  0.841465  0.258857  0.869844
# 8 -0.992072 -0.303936 -0.358257 -0.808484
# 9  1.752929  0.308758 -0.746995  1.677240

# %%
pieces = [df2[:3], df2[3:7], df2[7:]]

# %%
pieces
# Out:
# [          0         1         2         3
#  0 -0.145894  0.805844  0.537868 -0.352405
#  1  1.447758 -0.144260  0.443920  1.216330
#  2 -0.611848 -1.657801  0.419867  0.456660,
#            0         1         2         3
#  3 -0.216031 -0.515023  0.509460  2.874654
#  4 -0.462560  1.292320 -1.324338  0.225615
#  5  2.048822  0.814367  0.149044  1.109156
#  6 -1.170663 -1.536714  0.301065  0.898427,
#            0         1         2         3
#  7 -0.631017  0.841465  0.258857  0.869844
#  8 -0.992072 -0.303936 -0.358257 -0.808484
#  9  1.752929  0.308758 -0.746995  1.677240]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.145894  0.805844  0.537868 -0.352405
# 1  1.447758 -0.144260  0.443920  1.216330
# 2 -0.611848 -1.657801  0.419867  0.456660
# 3 -0.216031 -0.515023  0.509460  2.874654
# 4 -0.462560  1.292320 -1.324338  0.225615
# 5  2.048822  0.814367  0.149044  1.109156
# 6 -1.170663 -1.536714  0.301065  0.898427
# 7 -0.631017  0.841465  0.258857  0.869844
# 8 -0.992072 -0.303936 -0.358257 -0.808484
# 9  1.752929  0.308758 -0.746995  1.677240
